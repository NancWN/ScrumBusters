# %%
import pandas as pd
path = 'data/raw/messages.csv'
df = pd.read_csv(path)
df
# Out:
#                                            Unnamed: 0  \
# 0   10982_@CryptoDemonz 😈⚔️🕸 World's First Video G...
# 1   10980_@CryptoDemonz 😈⚔️🕸 World's First Video G...
# 2   10979_@CryptoDemonz 😈⚔️🕸 World's First Video G...
# 3   10978_@CryptoDemonz 😈⚔️🕸 World's First Video G...
# 4   10977_@CryptoDemonz 😈⚔️🕸 World's First Video G...
# 5       5619_Binance Pump Company® (Dubai)_2022-02-01
# 6       5618_Binance Pump Company® (Dubai)_2022-02-01
# 7       5617_Binance Pump Company® (Dubai)_2022-02-01
# 8       5616_Binance Pump Company® (Dubai)_2022-02-01
# 9       5615_Binance Pump Company® (Dubai)_2022-01-30
# 10                            102_Telegram_2022-02-01
# 11                             99_Telegram_2022-01-24
# 12                             70_Telegram_2022-01-23
# 13                             33_Telegram_2022-01-22
# 14                             25_Telegram_2022-01-22
# 15               7042_Crypto Profit Coach™_2022-02-01
# ...

# %%
import pickle
path = 'data/tele.pickle'
with open(path, 'rb') as f:
    channel_list = pickle.load(f)
channel_list
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Input In [8], in <module>
#       2 path = 'data/tele.pickle'
#       3 with open(path, 'rb') as f:
# ----> 4     channel_list = pickle.load(f)
#       5 channel_list
#
# EOFError: Ran out of input
